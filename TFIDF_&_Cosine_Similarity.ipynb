endment) Bill could cause in the region. However, the Citizenship Amendment Bill 2019 may help non-Muslims in Assam left out of the NRC to get the citizenship of India – without further hurdles. As the Citizenship Amendment Bill has not amended the original provisions, any foreigner, including a Muslim, can still apply for Indian citizenship under the normal process of naturalisation. Conclusion The chief opposition to the Citizenship (Amendment) Bill is that it discriminates on the basis of religion by identifying only non-Muslims refugees as those who would be eligible for Indian citizenship. Overseas Citizen of India (OCI) and CAB The Bill also proposes to incorporate a sub-section (d) to Section 7, providing for cancellation of Overseas Citizen of India (OCI) registration where the OCI card-holder has violated any provision of the Citizenship Act or any other law in force. Six religious communities – Hindus, Sikhs, Buddhists, Jains, Parsis and Christians – are considered eligible for Indian citizenship if they entered India on or before 31 December 2014, but not Muslims. Citizenship Amendment Bill (CAB) vs National Register for Citizens (NRC) The Centre has been trying to implement both the Citizenship Amendment Bill (CAB) and the National Register of Citizens (NRC). As per the critics, Citizenship (Amendment) Bill violates Article 14 of the Indian Constitution – the fundamental right which guarantees equality to all persons."

# %%
documents = [docA, docB]

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords') 
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # Remove stop words and calculate tfidf of each word

# %%
tfidf = TfidfVectorizer(stop_words = stop_words)

# %%
response = tfidf.fit_transform([docA, docB])

# %%
feature_names = tfidf.get_feature_names()
for col in response.nonzero()[1]:
    print (feature_names[col], ' - ', response[0, col])
# Out:
# boil  -  0.0563917895412616
# remain  -  0.0563917895412616
# continued  -  0.0563917895412616
# clampdown  -  0.0563917895412616
# internet  -  0.0563917895412616
# indefinite  -  0.0563917895412616
# stranded  -  0.0563917895412616
# remained  -  0.0563917895412616
# hundreds  -  0.0563917895412616
# come  -  0.0563917895412616
# time  -  0.0563917895412616
# usual  -  0.0563917895412616
# belief  -  0.0563917895412616
# firm  -  0.0563917895412616
# tranquility  -  0.0563917895412616
# sections  -  0.0563917895412616
# appeal  -  0.0563917895412616
# sincerely  -  0.0563917895412616
# aerodrome  -  0.0563917895412616
# transportation  -  0.0563917895412616
# road  -  0.0563917895412616
# blockage  -  0.0563917895412616
# due  -  0.1127835790825232
# disrupted  -  0.0563917895412616
# airport  -  0.1127835790825232
# dibrugarh  -  0.0563917895412616
# passengers  -  0.1127835790825232
# movement  -  0.0563917895412616
# ministry  -  0.0563917895412616
# ...

# %% [markdown]
# # TFIDF Matrix

# %%
# Scikit Learn
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

# Create the Document Term Matrix
count_vectorizer = CountVectorizer(stop_words='english')
count_vectorizer = CountVectorizer()
sparse_matrix = count_vectorizer.fit_transform(documents)

# OPTIONAL: Convert Sparse Matrix to Pandas Dataframe if you want to see the word frequencies.
doc_term_matrix = sparse_matrix.todense()
df = pd.DataFrame(doc_term_matrix, 
                  columns=count_vectorizer.get_feature_names(), 
                  index=['docA', 'docB'])
df
# Out:
#       100  11  14  19  1955  2014  ...  worried  would  year  years  yet  you
# docA    1   3   2   1     1     1  ...        1      1     1      2    1    3
# docB    0   0   1   0     1     2  ...        1      1     0      0    0    0
#
# [2 rows x 550 columns]

# %%
# Compute Cosine Similarity
from sklearn.metrics.pairwise import cosine_similarity
print(cosine_similarity(df, df))
# Out:
# [[1.         0.89399245]
#  [0.89399245 1.        ]]

# %% [markdown]
# # Similarity Score = 0.893
# # Both the documents are very Similar.
